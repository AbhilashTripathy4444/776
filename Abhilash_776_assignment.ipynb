# %%
import pandas as pd
ICMRTestingLabs=pd.read_excel("ICMRTestingLabs.xlsx")
ICMRTestingLabs
# Out:
#                                                    lab  \
# 0    ICMR-Regional Medical Research Centre, Port Blair
# 1    Tomo Riba Institute of Health & Medical Scienc...
# 2    Sri Venkateswara Institute of Medical Sciences...
# 3                  Rangaraya Medical College, Kakinada
# 4                 Sidhartha Medical College, Vijaywada
# ..                                                 ...
# 246               Apollo Gleneagles Hospitals, Kolkata
# 247                       Tata Medical Center, Kolkata
# 248  Laboratory Services, Peerless Hospitex Hospita...
# 249  AMRI Hospitals, Department of Laboratory Medic...
# 250            Suraksha Diagnostics Pvt. Ltd., Kolkata
#
#                                                address  pincode        city  \
# 0    ICMR-Regional Medical Research Centre, Post Ba...   744103  Port Blair
# 1    National Highway 52A, Old Assembly Complex, Na...   791110  Naharlagun
# ...

# %%
import numpy as np
df_morph = ICMRTestingLabs[["pincode"]].drop_duplicates()
df_morph.shape
# Out:
# (224, 1)

# %%
histplot = df_morph.hist([ 'pincode'])

# %%
ICMRTestingLabsState=ICMRTestingLabs.groupby('state',axis=0).sum()

print(type(ICMRTestingLabs.groupby('state', axis=0)))

ICMRTestingLabsState
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#                                            pincode
# state
# Andaman and Nicobar Islands                 744103
# Andhra Pradesh                             3653525
# Arunachal Pradesh                           791110
# Assam                                      3921349
# Bihar                                      4889536
# Chandigarh                                  320059
# Chhattisgarh                               1478101
# Dadra and Nagar Haveli and Daman and Diu    396230
# Delhi                                      1870588
# Goa                                         403202
# Gujarat                                    4545113
# Haryana                                    1233881
# Himachal Pradesh                            347002
# Jammu and Kashmir                           742123
# Jharkhand                                  2491034
# Karnataka                                  9083944
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel(r'C:\Users\User\Desktop\ICMRTestingLabs.xlsx')
print(df)
# Out:
#                                                    lab  \
# 0    ICMR-Regional Medical Research Centre, Port Blair
# 1    Tomo Riba Institute of Health & Medical Scienc...
# 2    Sri Venkateswara Institute of Medical Sciences...
# 3                  Rangaraya Medical College, Kakinada
# 4                 Sidhartha Medical College, Vijaywada
# ..                                                 ...
# 246               Apollo Gleneagles Hospitals, Kolkata
# 247                       Tata Medical Center, Kolkata
# 248  Laboratory Services, Peerless Hospitex Hospita...
# 249  AMRI Hospitals, Department of Laboratory Medic...
# 250            Suraksha Diagnostics Pvt. Ltd., Kolkata
#
#                                                address  pincode        city  \
# 0    ICMR-Regional Medical Research Centre, Post Ba...   744103  Port Blair
# 1    National Highway 52A, Old Assembly Complex, Na...   791110  Naharlagun
# ...

# %%
import pandas as pd
AgeGroupDetails=pd.read_excel("AgeGroupDetails.xlsx")
AgeGroupDetails
# Out:
#    Sno             AgeGroup  TotalCases  Percentage
# 0    1                  0-9          22      0.0318
# 1    2  2019-10-01 00:00:00          27      0.0390
# 2    3                20-29         172      0.2486
# 3    4                30-39         146      0.2110
# 4    5                40-49         112      0.1618
# 5    6                50-59          77      0.1113
# 6    7                60-69          89      0.1286
# 7    8                70-79          28      0.0405
# 8    9                 >=80          10      0.0145
# 9   10              Missing           9      0.0130

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

excel_file = 'AgeGroupDetails.xlsx'
df = pd.read_excel(excel_file)
values = df[['AgeGroup','TotalCases']]
ax = values.plot.line(x='AgeGroup',y='TotalCases',rot=0)
plt.show()

# %%
import pandas as pd
StatewiseTestingDetails=pd.read_excel("StatewiseTestingDetails.xlsx")
StatewiseTestingDetails
# Out:
#           Date        State  TotalSamples  Negative  Positive
# 0   2020-02-17       Kerala           423     406.0         3
# 1   2020-02-18       Kerala           425     420.0         3
# 2   2020-02-19       Kerala           432     423.0         3
# 3   2020-02-20       Kerala           433     423.0         3
# 4   2020-02-21       Kerala           437     426.0         3
# ..         ...          ...           ...       ...       ...
# 196 2020-04-10       Odisha          3249    3201.0        48
# 197 2020-04-10       Punjab          3461    2972.0       151
# 198 2020-04-10    Rajasthan         22324   20673.0       520
# 199 2020-04-10   Tamil Nadu          8410    6838.0       911
# 200 2020-04-11  Maharashtra         31841   30477.0      1364
#
# [201 rows x 5 columns]

# %%
import numpy as np
df_morph = StatewiseTestingDetails[[ "State", "TotalSamples", "Negative","Positive"]].drop_duplicates()
df_morph.shape
# Out:
# (199, 4)

# %%
histplot = df_morph.hist([ 'Negative','Positive'])

# %%
import pandas as pd
population_india_census2011=pd.read_excel("population_india_census2011.xlsx")
population_india_census2011
# Out:
#     Sno                   State / Union Territory  Population  \
# 0     1                             Uttar Pradesh   199812341
# 1     2                               Maharashtra   112374333
# 2     3                                     Bihar   104099452
# 3     4                               West Bengal    91276115
# 4     5                            Madhya Pradesh    72626809
# 5     6                                Tamil Nadu    72147030
# 6     7                                 Rajasthan    68548437
# 7     8                                 Karnataka    61095297
# 8     9                                   Gujarat    60439692
# 9    10                            Andhra Pradesh    49577103
# 10   11                                    Odisha    41974218
# 11   12                                 Telengana    35003674
# 12   13                                    Kerala    33406061
# 13   14                                 Jharkhand    32988134
# ...

# %%
import numpy as np
df_morph = population_india_census2011[[ "Population", "Gender Ratio", "Rural population","Urban population"]].drop_duplicates()
df_morph.shape
# Out:
# (36, 4)

# %%
boxplot = df_morph.boxplot([ 'Population','Gender Ratio','Rural population','Urban population'])

# %%
import matplotlib.pyplot as plt

population_india_census2011['Population'].plot(kind='pie',
                            figsize=(19,8),
                            autopct='%1.1f%%', 
                            startangle=60,  
                            pctdistance=1.12,
                            labels=None,   
                            )

plt.title('Total Population according to State')
plt.legend(labels=population_india_census2011.index, loc='upper left') 
plt.axis('equal')

plt.show()

# %%
import pandas as pd
covid_19_india=pd.read_excel("covid_19_india.xlsx")
covid_19_india
# Out:
#        Sno       Date      Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1 2020-01-30  18:00:00               Kerala                       1
# 1        2 2020-01-31  18:00:00               Kerala                       1
# 2        3 2020-02-01  18:00:00               Kerala                       2
# 3        4 2020-02-02  18:00:00               Kerala                       3
# 4        5 2020-02-03  18:00:00               Kerala                       3
# ...    ...        ...       ...                  ...                     ...
# 1020  1021 2020-04-16  17:00:00            Telengana                       -
# 1021  1022 2020-04-16  17:00:00              Tripura                       -
# 1022  1023 2020-04-16  17:00:00          Uttarakhand                       -
# 1023  1024 2020-04-16  17:00:00        Uttar Pradesh                       -
# 1024  1025 2020-04-16  17:00:00          West Bengal                       -
#
# ...

# %%
import numpy as np
df_morph = covid_19_india[[ "Confirmed", "Deaths"]].drop_duplicates()
df_morph.shape
# Out:
# (356, 2)

# %%
histplot = df_morph.hist([ 'Confirmed','Deaths'])
